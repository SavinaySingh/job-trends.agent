# %%
import os
import pickle
import pandas as pd
import google.generativeai as genai
from tqdm import tqdm

# Setup
PICKLE_FOLDER = './PickleFiles'
OUTPUT_CSV = './kg_triples.csv'
GENERATION_MODEL = 'gemini-2.0-flash'
MAX_PAGES_PER_DOC = 10  # Limit to avoid too many tokens
OUTPUT_JSON = './kg_triples.json'
CHECKPOINT_FILE = './checkpoint.json'

# %%
# Authenticate Gemini
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
model = genai.GenerativeModel(GENERATION_MODEL)

def load_documents(pickle_folder):
    files = [f for f in os.listdir(pickle_folder) if f.endswith('.pkl')]
    documents = []
    for file in files:
        with open(os.path.join(pickle_folder, file), 'rb') as f:
            data = pickle.load(f)
            if 'pages' in data:
                documents.append({'filename': file, 'pages': data['pages']})
    return documents

def build_prompt(text_chunk):
    return f"""
Given the following text, extract clear and factual knowledge graph triples in the format:
(subject) — [predicate] → (object)

Text: {text_chunk}


Only output the list of triples. Ignore speculative or vague statements. Avoid duplicates.
"""

def extract_triples_from_text(text):
    prompt = build_prompt(text)
    try:
        response = model.generate_content(prompt)
        return response.text.strip()
    except Exception as e:
        print(f"Error generating response: {e}")
        return ""

def parse_triples(output_text):
    triples = []
    for line in output_text.split("\n"):
        if '—' in line and '→' in line:
            try:
                subject, rest = line.split('—')
                predicate, obj = rest.split('→')
                triples.append({
                    'subject': subject.strip(" ()"),
                    'predicate': predicate.strip(" []"),
                    'object': obj.strip(" ()")
                })
            except ValueError:
                continue  # Skip badly formatted lines
    return triples

# %%
def load_existing_triples(output_json):
    if not os.path.exists(output_json):
        return [], set()
    with open(output_json, 'r') as f:
        data = json.load(f)
        processed = {item['source_file'] for item in data}
        return data, processed
    
documents = load_documents(PICKLE_FOLDER)
existing_data, processed_files = load_existing_triples(OUTPUT_JSON)
new_triples = []

# %%
import json

# %%
def load_documents(folder):
    return [
        {'filename': f, 'path': os.path.join(folder, f)}
        for f in os.listdir(folder)
        if f.endswith('.pkl')
    ]

def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        return pickle.load(f)

def load_json_file(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            return json.load(f)
    return []

def save_json_file(data, file_path):
    with open(file_path, 'w') as f:
        json.dump(data, f, indent=2)

# %%
import time
for doc in tqdm(documents, desc="Processing documents"):
    if doc['filename'] in processed_files:
        continue  # Already done

    try:
        
        data = load_pickle('./PickleFiles/'+doc['filename'])
        pages = data.get('pages', [])[:MAX_PAGES_PER_DOC]
    except Exception as e:
        print(f"❌ Failed to load {doc['filename']}: {e}")
        continue

    for i, page in enumerate(pages):
        triples_text = extract_triples_from_text(page)
        triples = parse_triples(triples_text)
        for t in triples:
            t['source_file'] = doc['filename']
            t['page_number'] = i
        new_triples.extend(triples)

    # Update checkpoint after successful file
    processed_files.add(doc['filename'])
    save_json_file(list(processed_files), CHECKPOINT_FILE)
    time.sleep(50)
# Out:
# Processing documents: 100%|██████████| 14/14 [15:00<00:00, 64.33s/it]

# %%
all_triples = load_json_file(OUTPUT_JSON)

all_triples.extend(new_triples)
save_json_file(all_triples, OUTPUT_JSON)

print(f"\n✅ {len(new_triples)} new triples saved to {OUTPUT_JSON}")
print(f"📍 Checkpoint updated: {CHECKPOINT_FILE}")
# Out:
# ✅ 1437 new triples saved to ./kg_triples.json
# 📍 Checkpoint updated: ./checkpoint.json

# %%
import json
json.load(open(OUTPUT_JSON, 'r'))
# Out:
# [{'subject': 'The Future of Jobs Report 2020',
#   'predicate': 'publisher',
#   'object': 'World Economic Forum',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'The Future of Jobs Report 2020',
#   'predicate': 'publication date',
#   'object': 'October 2020',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'cover',
#   'predicate': 'depicts',
#   'object': "modern building's curved facade",
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 0},
#  {'subject': "modern building's curved facade",
#   'predicate': 'background color',
#   'object': 'light blue',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'title',
#   'object': 'The Future of Jobs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'hasPart',
#   'object': 'Part 1: "Tracking the Future of Jobs"',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'hasPart',
#   'object': 'Part 2',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Part 1: "Tracking the Future of Jobs"',
#   'predicate': 'focusesOn',
#   'object': 'labour market outlook',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'includes',
#   'object': 'methodology',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'includes',
#   'object': 'contributors',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'includes',
#   'object': 'acknowledgements',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Report: "The Future of Jobs"',
#   'predicate': 'includes',
#   'object': 'survey partners',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Part 2',
#   'predicate': 'provides',
#   'object': 'country profiles',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Part 2',
#   'predicate': 'provides',
#   'object': 'industry profiles',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Part 2',
#   'predicate': 'includes',
#   'object': "user's guide",
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'edition',
#   'object': 'third',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'organization',
#   'object': 'World Economic Forum',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'date',
#   'object': 'October 2020',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'cause',
#   'object': 'economic and social disruption',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'add to',
#   'object': 'pre-existing income inequality',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'add to',
#   'object': 'technological displacement of jobs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Global Reset',
#   'predicate': 'need',
#   'object': 'more equitable and sustainable socio-economic system',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'maps',
#   'object': 'future job skills',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'tracks',
#   'object': 'pace of technological change',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'job creation',
#   'predicate': 'outpace',
#   'object': 'job destruction',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'economic contraction',
#   'predicate': 'slowing',
#   'object': 'growth',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'collaboration with',
#   'object': 'governments',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'collaboration with',
#   'object': "World Economic Forum's partners",
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'report',
#   'predicate': 'about',
#   'object': 'future of jobs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'report',
#   'predicate': 'emphasizes',
#   'object': 'short window of opportunity',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'automation',
#   'predicate': 'leads to',
#   'object': 'positive outcomes',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'positive outcomes',
#   'predicate': 'include',
#   'object': 'good jobs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'positive outcomes',
#   'predicate': 'include',
#   'object': 'improved quality of life',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'report',
#   'predicate': 'uses data from',
#   'object': 'LinkedIn',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'report',
#   'predicate': 'uses data from',
#   'object': 'Coursera',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'report',
#   'predicate': 'uses data from',
#   'object': 'ADP',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'report',
#   'predicate': 'uses data from',
#   'object': 'FutureFit.AI',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'Future of Jobs Report 2020',
#   'predicate': 'focuses on',
#   'object': 'impact of COVID-19 pandemic',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Future of Jobs Report 2020',
#   'predicate': 'focuses on',
#   'object': 'accelerated technological adoption',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'impacts',
#   'object': 'future of work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Technological adoption',
#   'predicate': 'includes',
#   'object': 'cloud computing',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Technological adoption',
#   'predicate': 'includes',
#   'object': 'big data',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Technological adoption',
#   'predicate': 'includes',
#   'object': 'AI',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Pandemic',
#   'predicate': 'causes',
#   'object': 'workforce reductions',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Automation',
#   'predicate': 'causes',
#   'object': 'workforce reductions',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Pandemic',
#   'predicate': 'causes',
#   'object': 'increased use of contractors',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Automation',
#   'predicate': 'causes',
#   'object': 'increased use of contractors',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Pandemic',
#   'predicate': 'causes',
#   'object': 'job transformations',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Automation',
#   'predicate': 'causes',
#   'object': 'job transformations',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Division of labor',
#   'predicate': 'is between',
#   'object': 'humans and machines',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Shift in division of labor',
#   'predicate': 'results in',
#   'object': 'job displacement',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Shift in division of labor',
#   'predicate': 'results in',
#   'object': 'job creation',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Skills gaps',
#   'predicate': 'require',
#   'object': 'reskilling',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Workforce',
#   'predicate': 'experiences shift to',
#   'object': 'digitalization',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Workforce',
#   'predicate': 'experiences shift to',
#   'object': 'remote work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'reskilling and upskilling',
#   'predicate': 'context',
#   'object': 'economic shifts and technological advancements',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'individuals',
#   'predicate': 'seeking',
#   'object': 'online learning opportunities',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'employers',
#   'predicate': 'recognizing',
#   'object': 'value of human capital investment',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'reskilling',
#   'predicate': 'opportunity',
#   'object': 'shrinking window',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'public sector',
#   'predicate': 'support for',
#   'object': 'reskilling initiatives',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'public sector',
#   'predicate': 'role in',
#   'object': 'providing incentives',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'public sector',
#   'predicate': 'role in',
#   'object': 'providing safety nets',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'public sector',
#   'predicate': 'role in',
#   'object': 'addressing educational system shortcomings',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'report',
#   'predicate': 'has title',
#   'object': 'The Future of Jobs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'publication date',
#   'object': 'October 2020',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'part 1',
#   'predicate': 'is titled',
#   'object': 'Tracking the Future of Jobs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'has part',
#   'object': 'part 1',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'page',
#   'predicate': 'is part of',
#   'object': 'report',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'page',
#   'predicate': 'page number',
#   'object': '7',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'edition number',
#   'object': 'third',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'year',
#   'object': '2020',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'examines',
#   'object': "labour market's outlook",
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'highlights',
#   'object': 'technological augmentation of work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological augmentation of work',
#   'predicate': 'results in',
#   'object': 'job displacement',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological augmentation of work',
#   'predicate': 'results in',
#   'object': 'creation of new roles',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological advancements',
#   'predicate': 'offer opportunities in',
#   'object': 'green economy',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological advancements',
#   'predicate': 'offer opportunities in',
#   'object': 'AI',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological advancements',
#   'predicate': 'offer opportunities in',
#   'object': 'engineering',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological advancements',
#   'predicate': 'pose',
#   'object': 'skills shortages',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'technological advancements',
#   'predicate': 'pose',
#   'object': 'need for significant reskilling and upskilling',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'workforce',
#   'predicate': 'disruption projected by 2025',
#   'object': '15%',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'workforce',
#   'predicate': 'complete displacement projected by 2025',
#   'object': '6%',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Companies',
#   'predicate': 'are planning to',
#   'object': 'reskill or upskill the majority of their workforce',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Report',
#   'predicate': 'emphasizes',
#   'object': 'importance of human interaction',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Report',
#   'predicate': 'highlights',
#   'object': 'continuing demand for roles in care',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Report',
#   'predicate': 'highlights',
#   'object': 'continuing demand for roles in marketing',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Report',
#   'predicate': 'highlights',
#   'object': 'continuing demand for roles in content production',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'focuses on',
#   'object': 'impact of COVID-19 pandemic',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Future of Jobs Report',
#   'predicate': 'focuses on',
#   'object': 'impact of Fourth Industrial Revolution',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'caused',
#   'object': 'economic effects',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'caused',
#   'object': 'business closures',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Automation',
#   'predicate': 'is a',
#   'object': 'long-term trend',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Globalization',
#   'predicate': 'is a',
#   'object': 'long-term trend',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Health Shock',
#   'predicate': 'has',
#   'object': 'asymmetric nature',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Report',
#   'predicate': 'highlights',
#   'object': 'job transitions',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Report',
#   'predicate': 'emphasizes',
#   'object': 'importance of creating learning organizations',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Report',
#   'predicate': 'emphasizes',
#   'object': 'importance of fostering equitable futures of work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Report',
#   'predicate': 'emphasizes',
#   'object': 'importance of fostering prosperous futures of work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Technological advancements',
#   'predicate': 'have historically led to',
#   'object': 'increased prosperity',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Current situation',
#   'predicate': 'has deepened',
#   'object': 'existing inequalities',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Current situation',
#   'predicate': 'has accelerated',
#   'object': 'arrival of the future of work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Current situation',
#   'predicate': 'requires',
#   'object': '"Great Reset"',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Data from US',
#   'predicate': 'shows',
#   'object': 'displacement of jobs due to automation',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Automation',
#   'predicate': 'affects',
#   'object': 'routine manual tasks',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Pandemic',
#   'predicate': 'has exacerbated',
#   'object': 'challenges of automation',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Pandemic',
#   'predicate': 'necessitates',
#   'object': 'remote work',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Pandemic',
#   'predicate': 'necessitates',
#   'object': 'physical distancing',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Figure 1',
#   'predicate': 'shows',
#   'object': 'employment trends for jobs in the United States at high risk of automation',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Employment trends',
#   'predicate': 'time period',
#   'object': '2007-2018',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'impact on',
#   'object': 'employment',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'caused',
#   'object': 'contraction of economic activity',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'COVID-19 pandemic',
#   'predicate': 'caused',
#   'object': 'job losses',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Job losses',
#   'predicate': 'affected',
#   'object': 'SMEs',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Job losses',
#   'predicate': 'affected',
#   'object': 'sectors reliant on in-person contact',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Unemployment during major disruptions',
#   'predicate': 'historically peaks at or exceeds',
#   'object': '10%',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Unemployment during periods of stability',
#   'predicate': 'hovers around',
#   'object': '5%',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'workforce in 35 countries',
#   'predicate': 'at high risk of',
#   'object': 'job loss',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'job loss',
#   'predicate': 'caused by',
#   'object': 'pandemic',
#   'source_file': 'WEF_Future_of_Jobs_2020.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Working paper',
#   'predicate': 'title',
#   'object': '"The Australian labour market and IT-enabled technological change"',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Working paper',
#   'predicate': 'publisher',
#   'object': 'Melbourne Institute, Applied Economic & Social Research',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Working paper',
#   'predicate': 'author',
#   'object': 'Jeff Borland',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Working paper',
#   'predicate': 'author',
#   'object': 'Michael Coelli',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Working paper',
#   'predicate': 'publication number',
#   'object': '01/23',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Working paper',
#   'predicate': 'available via',
#   'object': 'SSRN',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'Document',
#   'predicate': 'instance of',
#   'object': 'working paper',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'publisher',
#   'object': 'Melbourne Institute: Applied Economic & Social Research',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'title',
#   'object': '"The Australian labour market and IT-enabled technological change"',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'prepared for',
#   'object': 'conference in 2022',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'acknowledges',
#   'object': 'contributions from several individuals',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'acknowledges',
#   'object': 'ARC Discovery grant',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'status',
#   'object': 'for discussion purposes only',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'Document',
#   'predicate': 'status',
#   'object': 'has not undergone peer review',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'paper',
#   'predicate': 'reviews impact of',
#   'object': 'IT-enabled technological change on the Australian labor market',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'IT-enabled technological change',
#   'predicate': 'affects',
#   'object': 'total work',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'IT-enabled technological change',
#   'predicate': 'affects',
#   'object': 'type of work and skills demanded',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'IT-enabled technological change',
#   'predicate': 'affects',
#   'object': 'inequality',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'IT-enabled technological change',
#   'predicate': 'affects',
#   'object': 'gig economy',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'paper',
#   'predicate': 'includes',
#   'object': 'discussion of policy implications',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'paper',
#   'predicate': 'includes',
#   'object': 'discussion of lessons learned',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'paper',
#   'predicate': 'includes',
#   'object': 'JEL classifications',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'paper',
#   'predicate': 'includes',
#   'object': 'keywords',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'paper',
#   'predicate': 'reviews',
#   'object': 'impact of IT-enabled technological change',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'paper',
#   'predicate': 'reviews',
#   'object': 'impact on the Australian labor market',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'IT-enabled change',
#   'predicate': 'affects',
#   'object': 'tasks',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'IT-enabled change',
#   'predicate': 'affects',
#   'object': 'job types',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'IT-enabled change',
#   'predicate': 'affects',
#   'object': 'skills',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'IT-enabled change',
#   'predicate': 'affects',
#   'object': 'income shares',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'impacts',
#   'predicate': 'are seen as',
#   'object': 'latest stage in technological developments',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'public policy',
#   'predicate': 'should facilitate',
#   'object': 'adoption of new technologies',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'public policy',
#   'predicate': 'should address',
#   'object': 'associated adjustments',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'public policy',
#   'predicate': 'should address',
#   'object': 'distributional consequences',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'paper',
#   'predicate': 'examines impact of',
#   'object': 'IT-enabled technological change on the Australian labor market',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 2',
#   'predicate': 'details',
#   'object': 'how IT-enabled technological change affects Australian labor market',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 3',
#   'predicate': 'assesses impacts on',
#   'object': 'total amount of work',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 3',
#   'predicate': 'assesses impacts on',
#   'object': 'type of work',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 3',
#   'predicate': 'assesses impacts on',
#   'object': 'skills',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 3',
#   'predicate': 'assesses impacts on',
#   'object': 'inequality',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 3',
#   'predicate': 'assesses impacts on',
#   'object': 'gig economy',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 4',
#   'predicate': 'evaluates',
#   'object': 'policy implications',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 4',
#   'predicate': 'offers',
#   'object': 'lessons learned',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Section 5',
#   'predicate': 'suggests',
#   'object': 'avenues for future research',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'paper',
#   'predicate': 'uses',
#   'object': 'canonical model',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'firms',
#   'predicate': 'choose',
#   'object': 'production methods',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'production methods',
#   'predicate': 'include',
#   'object': 'labor',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'production methods',
#   'predicate': 'include',
#   'object': 'capital',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'firms',
#   'predicate': 'minimize',
#   'object': 'costs',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'paper',
#   'predicate': 'highlights',
#   'object': 'displacement',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'paper',
#   'predicate': 'highlights',
#   'object': 'reinstatement',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'paper',
#   'predicate': 'highlights',
#   'object': 'augmentation',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'paper',
#   'predicate': 'highlights',
#   'object': 'productivity changes',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'paper',
#   'predicate': 'cites evidence from',
#   'object': 'recent studies',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'recent studies',
#   'predicate': 'link',
#   'object': 'patent activity to labor displacement',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'recent studies',
#   'predicate': 'link',
#   'object': 'patent activity to labor reinstatement',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Displacement',
#   'predicate': 'replaces',
#   'object': 'labor',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Reinstatement',
#   'predicate': 'creates',
#   'object': 'new tasks',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'New technologies',
#   'predicate': 'require',
#   'object': 'human labor',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Augmentation',
#   'predicate': 'increases',
#   'object': 'productivity',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Augmentation',
#   'predicate': 'impacts',
#   'object': 'existing labor',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Technology',
#   'predicate': 'increases',
#   'object': 'productivity',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Productivity',
#   'predicate': 'leads to',
#   'object': 'Cost savings',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Cost savings',
#   'predicate': 'increase',
#   'object': 'consumer income',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Increased Consumer Income',
#   'predicate': 'boosts',
#   'object': 'demand',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Demand',
#   'predicate': 'impacts',
#   'object': 'labor demand',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Firm adoption of new technologies',
#   'predicate': 'focuses on',
#   'object': 'effect on labor demand',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Impact',
#   'predicate': 'determined by',
#   'object': 'effect on the adopting firm',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Impact',
#   'predicate': 'determined by',
#   'object': 'spill-over effects on other firms',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Spillover effects',
#   'predicate': 'can be',
#   'object': 'negative',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Spillover effects',
#   'predicate': 'can be',
#   'object': 'positive',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Robot adoption',
#   'predicate': 'direct impact',
#   'object': 'displacement of low-skill workers',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Displacement of low-skill workers',
#   'predicate': 'can be offset by',
#   'object': 'increased employment of higher-skill workers',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Displacement of low-skill workers',
#   'predicate': 'can be offset by',
#   'object': 'reshoring of production',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Technological advancements',
#   'predicate': 'lead to',
#   'object': 'shift in demand towards high-skill workers',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'routine-biased technological change',
#   'predicate': 'posits',
#   'object': 'jobs involving routine, programmable tasks are most susceptible to automation',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'jobs involving routine, programmable tasks',
#   'predicate': 'are susceptible to',
#   'object': 'automation',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'jobs requiring non-routine tasks',
#   'predicate': 'are less easily',
#   'object': 'automated',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'routine task',
#   'predicate': 'is defined as',
#   'object': 'methodical repetition of a procedure',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'routine task',
#   'predicate': 'is',
#   'object': 'easily automated by machines',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Document',
#   'predicate': 'discusses',
#   'object': 'impacts of IT-enabled technologies on the Australian labor market',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'IT-enabled technologies',
#   'predicate': 'affected',
#   'object': 'how firms sell',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'IT-enabled technologies',
#   'predicate': 'affected',
#   'object': 'how labor markets are organized',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'IT-enabled technologies',
#   'predicate': 'affected',
#   'object': 'bargaining power',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Key changes',
#   'predicate': 'include',
#   'object': 'lower costs for suppliers to reach wider markets',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Key changes',
#   'predicate': 'include',
#   'object': 'the rise of platform-based work',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Document',
#   'predicate': 'analyzes',
#   'object': 'impact on four main labor market outcomes',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Labor market outcomes',
#   'predicate': 'include',
#   'object': 'the total amount of work',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Labor market outcomes',
#   'predicate': 'include',
#   'object': 'the type of work and skills demanded',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Labor market outcomes',
#   'predicate': 'include',
#   'object': 'inequality',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Labor market outcomes',
#   'predicate': 'include',
#   'object': 'the gig economy',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Document',
#   'predicate': 'details',
#   'object': 'rapid growth in the use of IT in production in Australia',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Growth in IT use in Australia',
#   'predicate': 'shows',
#   'object': 'increase in the share of capital stock accounted for by computers and software',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'Figure 1a',
#   'predicate': 'displays',
#   'object': 'net capital stock of computers, software, and electronic/electrical equipment',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1a',
#   'predicate': 'shows trend in',
#   'object': 'Australia',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1a',
#   'predicate': 'covers period',
#   'object': '1966 to 2022',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'net capital stock of computers, software, and electronic/electrical equipment',
#   'predicate': 'shows increase',
#   'object': '1990s to 2022',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1b',
#   'predicate': 'illustrates',
#   'object': 'stock of industrial robots in use',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1b',
#   'predicate': 'shows trend in',
#   'object': 'Australia',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1b',
#   'predicate': 'covers period',
#   'object': '1966 to 2022',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'stock of industrial robots in use',
#   'predicate': 'increased',
#   'object': '1993 to early 2010s',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'stock of industrial robots in use',
#   'predicate': 'declined',
#   'object': 'following decade',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1a',
#   'predicate': 'uses data from source',
#   'object': 'ABS',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1a',
#   'predicate': 'uses data from source',
#   'object': 'IFR',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1b',
#   'predicate': 'uses data from source',
#   'object': 'ABS',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'Figure 1b',
#   'predicate': 'uses data from source',
#   'object': 'IFR',
#   'source_file': 'ssrn-4326257.pdf.pkl',
#   'page_number': 9},
#  {'subject': 'OECD Artificial Intelligence Paper',
#   'predicate': 'publication date',
#   'object': 'April 2024',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'OECD Artificial Intelligence Paper',
#   'predicate': 'publication number',
#   'object': '14',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'OECD Artificial Intelligence Paper',
#   'predicate': 'title',
#   'object': 'Artificial Intelligence and the Changing Demand for Skills in the Labour Market',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'OECD Artificial Intelligence Paper',
#   'predicate': 'publisher',
#   'object': 'OECD',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 0},
#  {'subject': 'OECD Working Paper',
#   'predicate': 'concerns',
#   'object': 'artificial intelligence and the changing demand for skills in the labour market',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD',
#   'predicate': 'is',
#   'object': 'Organisation for Economic Co-operation and Development',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD Working Paper',
#   'predicate': 'authorship disclaimer',
#   'object': 'Opinions and arguments are those of the authors, not necessarily the official views of the OECD or its member countries',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD Working Paper',
#   'predicate': 'presents',
#   'object': 'preliminary research',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD Working Paper',
#   'predicate': 'intended to',
#   'object': 'stimulate discussion',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD Working Paper',
#   'predicate': 'includes',
#   'object': 'standard disclaimer regarding the depiction of geographical boundaries',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD Working Paper',
#   'predicate': 'provides',
#   'object': "link to the OECD's terms and conditions for the use of the document",
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'OECD report',
#   'predicate': 'author',
#   'object': 'Andrew Green',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'OECD report',
#   'predicate': 'examines',
#   'object': 'impact of artificial intelligence (AI) on skill demands in the labor market',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'OECD report',
#   'predicate': 'finds',
#   'object': 'AI changes job tasks',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'OECD report',
#   'predicate': 'finds',
#   'object': 'AI changes required skills',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'study',
#   'predicate': 'estimates',
#   'object': 'demand for management and business skills has increased',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'demand for management and business skills',
#   'predicate': 'includes',
#   'object': 'project management',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'demand for management and business skills',
#   'predicate': 'includes',
#   'object': 'finance',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'demand for management and business skills',
#   'predicate': 'includes',
#   'object': 'administration',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'OECD report',
#   'predicate': 'highlights',
#   'object': 'increase in vacancies requiring emotional, cognitive, or digital skills',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'Artificial Intelligence',
#   'predicate': 'impacts',
#   'object': 'demand for skills in the labor market',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'employees exposed to AI',
#   'predicate': 'require',
#   'object': 'job tasks',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'employees exposed to AI',
#   'predicate': 'require',
#   'object': 'skills',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'management and commerce skills',
#   'predicate': 'include',
#   'object': 'project management',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'management and commerce skills',
#   'predicate': 'include',
#   'object': 'finance',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'management and commerce skills',
#   'predicate': 'include',
#   'object': 'administration',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'management and commerce skills',
#   'predicate': 'include',
#   'object': 'office work',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'AI-exposed professions',
#   'predicate': 'demand',
#   'object': 'management and commerce skills',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'AI',
#   'predicate': 'impacts',
#   'object': 'demand for skills',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'AI',
#   'predicate': 'changes',
#   'object': 'job tasks',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'AI',
#   'predicate': 'changes',
#   'object': 'required competencies',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'management and business skills',
#   'predicate': 'related to',
#   'object': 'project management',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'management and business skills',
#   'predicate': 'related to',
#   'object': 'finance',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'management and business skills',
#   'predicate': 'related to',
#   'object': 'administration',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'management and business skills',
#   'predicate': 'related to',
#   'object': 'clerical work',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'management and business skills',
#   'predicate': 'demand in',
#   'object': 'high-AI-potential jobs',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Publication',
#   'predicate': 'concerns',
#   'object': 'artificial intelligence',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Publication',
#   'predicate': 'concerns',
#   'object': 'labor market',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Publication',
#   'predicate': 'is part of',
#   'object': "OECD's AI-WIPS program",
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': "OECD's AI-WIPS program",
#   'predicate': 'aims to provide',
#   'object': 'policymakers with data',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': "OECD's AI-WIPS program",
#   'predicate': 'focuses on',
#   'object': "AI's effects on work",
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Work',
#   'predicate': 'supported by',
#   'object': 'German Federal Ministry of Labour and Social Affairs',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Publication',
#   'predicate': 'involves contributions from',
#   'object': 'OECD departments',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'employment',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'labor',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'social affairs',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'science',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'technology',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'innovation',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'OECD departments',
#   'predicate': 'focused on',
#   'object': 'education',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'report',
#   'predicate': 'title',
#   'object': '"Artificial Intelligence and the Changing Demand for Skills in the Labour Market"',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'has part',
#   'object': 'introduction',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'has part',
#   'object': 'measurement of AI exposure and skills in job vacancies',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'has part',
#   'object': 'changes in occupational skill demand from AI exposure',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'has part',
#   'object': 'changing skill demands due to establishment-level AI exposure',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'includes',
#   'object': 'résumé',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'includes',
#   'object': 'abstract',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'includes',
#   'object': 'acknowledgements',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'report',
#   'predicate': 'includes',
#   'object': 'executive summary',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'document',
#   'predicate': 'presents findings on',
#   'object': 'changing demand for skills in the labor market',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'changing demand for skills in the labor market',
#   'predicate': 'due to',
#   'object': 'artificial intelligence',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'document',
#   'predicate': 'includes',
#   'object': 'figures showing share of vacancies with high AI exposure',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'document',
#   'predicate': 'includes',
#   'object': 'figures showing share of vacancies demanding AI skills',
#   'source_file': '88684e36-en.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'document',
#   'predicate': 'includes',
#   'object': 'figures showing most demanded skills in high-exposure occupations',
# ...
#   'object': 'mining and metals',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'table of contents',
#   'predicate': 'contains section',
#   'object': 'cross-sector solutions',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'table of contents',
#   'predicate': 'contains section',
#   'object': 'conclusion',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'table of contents',
#   'predicate': 'contains section',
#   'object': 'contact information',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'table of contents',
#   'predicate': 'contains section',
#   'object': 'endnotes',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 1},
#  {'subject': 'decarbonization',
#   'predicate': 'creates',
#   'object': 'new ecosystems',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'decarbonization',
#   'predicate': 'creates',
#   'object': 'new technologies',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'carbon neutrality',
#   'predicate': 'has target date',
#   'object': '2050',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'report',
#   'predicate': 'explores',
#   'object': 'how companies in various E&R sectors can accelerate decarbonization',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'report',
#   'predicate': 'explores',
#   'object': 'how companies in various E&R sectors can set meaningful interim targets by 2030',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 2},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'customer demands',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'employee demands',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'community demands',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'investor pressure',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'policy',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'government targets',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'transition to clean energy',
#   'predicate': 'driven by',
#   'object': 'technological advancements',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'technological advancements',
#   'predicate': 'leading to',
#   'object': 'lower operational costs',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'public',
#   'predicate': 'supports',
#   'object': 'climate action',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'consumer',
#   'predicate': 'demands',
#   'object': 'sustainable products',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'consumer',
#   'predicate': 'demands',
#   'object': 'sustainable practices',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'younger employees',
#   'predicate': 'prioritize',
#   'object': 'working for companies with a social benefit',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'employee activism',
#   'predicate': 'monitoring',
#   'object': 'company responses to climate change',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'governments',
#   'predicate': 'responding to',
#   'object': 'public pressure',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'governments',
#   'predicate': 'setting',
#   'object': 'carbon reduction targets',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'governments',
#   'predicate': 'enacting',
#   'object': 'green legislation',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 3},
#  {'subject': 'EU',
#   'predicate': 'sets',
#   'object': 'ambitious carbon-reduction goals',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'China',
#   'predicate': 'sets',
#   'object': 'ambitious carbon-reduction goals',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'EU',
#   'predicate': 'committed to',
#   'object': 'Paris Agreement',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'China',
#   'predicate': 'committed to',
#   'object': 'Paris Agreement',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Government',
#   'predicate': 'adopts',
#   'object': 'carbon pricing',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Carbon pricing',
#   'predicate': 'includes',
#   'object': 'direct taxes',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Carbon pricing',
#   'predicate': 'includes',
#   'object': 'cap-and-trade programs',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'BlackRock',
#   'predicate': 'has',
#   'object': 'sustainability strategy',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Sustainability strategy',
#   'predicate': 'includes',
#   'object': 'divesting from high-emission companies',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Sustainability strategy',
#   'predicate': 'includes',
#   'object': 'incorporating ESG criteria into investment decisions',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Climate Action 100+',
#   'predicate': 'is',
#   'object': 'investor-led initiative',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Decreasing technology costs',
#   'predicate': 'facilitates',
#   'object': 'decarbonization efforts',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Decarbonization efforts',
#   'predicate': 'for',
#   'object': 'energy and resource companies',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 4},
#  {'subject': 'Infographic',
#   'predicate': 'discusses',
#   'object': '2030 decarbonization challenge',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Infographic',
#   'predicate': 'discusses',
#   'object': 'future of energy',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Infographic',
#   'predicate': 'highlights',
#   'object': 'decreasing cost of battery packs',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Infographic',
#   'predicate': 'highlights',
#   'object': 'advancements in digital technology',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Energy and Resource companies',
#   'predicate': 'take',
#   'object': 'proactive steps to reduce emissions',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Energy and Resource companies',
#   'predicate': 'transition to',
#   'object': 'renewable energy',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Deloitte survey',
#   'predicate': 'reveals',
#   'object': 'E&R executives have decarbonization plans',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Infographic',
#   'predicate': 'explores',
#   'object': 'four potential future scenarios for energy in 2035',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Model',
#   'predicate': 'considers',
#   'object': 'uncertainties',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Model',
#   'predicate': 'considers',
#   'object': 'trends',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'categorized as',
#   'object': 'proactive societal responses to climate change',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'categorized as',
#   'object': 'reactive societal responses to climate change',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'divided by',
#   'object': 'independent/regional global economies',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'divided by',
#   'object': 'open/collaborative global economies',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'are',
#   'object': '"Ready, set, innovate"',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'are',
#   'object': '"One team, one dream"',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'are',
#   'object': '"Me and my resource"',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Scenarios',
#   'predicate': 'are',
#   'object': '"Rising tide"',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': "Each scenario's description",
#   'predicate': 'details',
#   'object': 'characteristics in terms of societal response',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': "Each scenario's description",
#   'predicate': 'details',
#   'object': 'characteristics in terms of economic structure',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Infographic',
#   'predicate': 'provides',
#   'object': 'link to website with more information',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 5},
#  {'subject': 'Decarbonization',
#   'predicate': 'challenge year',
#   'object': '2030',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Power and utilities sector',
#   'predicate': 'driver of transition',
#   'object': 'decarbonization',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Emissions from leading companies',
#   'predicate': 'decrease start year',
#   'object': '2015',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Enel',
#   'predicate': 'carbon-neutral target year',
#   'object': '2030',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Mining and metals companies',
#   'predicate': 'action',
#   'object': 'reduce emissions',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Oil, gas, and chemical companies',
#   'predicate': 'action',
#   'object': 'investing in renewables',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Oil, gas, and chemical companies',
#   'predicate': 'action',
#   'object': 'diversifying their businesses',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 6},
#  {'subject': 'Decarbonization',
#   'predicate': 'focuses on',
#   'object': 'energy sector',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Investment',
#   'predicate': 'needed in',
#   'object': 'low-carbon technologies',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Investment',
#   'predicate': 'amount',
#   'object': 'US$5 billion annually',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Companies',
#   'predicate': 'shifting to',
#   'object': 'renewable energy sources',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Companies',
#   'predicate': 'implementing',
#   'object': 'circular economy principles',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Energy, Resources & Industrials industry',
#   'predicate': 'emitted',
#   'object': '4.53 billion tonnes of carbon dioxide',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Energy, Resources & Industrials industry',
#   'predicate': 'time period',
#   'object': 'between 2017 and mid-2019',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Decarbonization',
#   'predicate': 'requires',
#   'object': 'transformational shift',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Document',
#   'predicate': 'examines decarbonization across',
#   'object': 'chemicals sector',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Document',
#   'predicate': 'examines decarbonization across',
#   'object': 'oil and gas sector',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Document',
#   'predicate': 'examines decarbonization across',
#   'object': 'mining and metals sector',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Document',
#   'predicate': 'examines decarbonization across',
#   'object': 'power/utilities/renewables sector',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'Document',
#   'predicate': 'uses',
#   'object': "Greenhouse Gas Protocol's Scope 1, 2, and 3 emissions framework",
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 7},
#  {'subject': 'image',
#   'predicate': 'has_background',
#   'object': 'dark background',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'image',
#   'predicate': 'has_design',
#   'object': 'teal and green abstract design',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'image',
#   'predicate': 'design_location',
#   'object': 'top',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'image',
#   'predicate': 'has_icon',
#   'object': 'beaker icon',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'beaker icon',
#   'predicate': 'represents',
#   'object': 'Chemicals',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'image',
#   'predicate': 'has_icon',
#   'object': 'oil derrick icon',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'oil derrick icon',
#   'predicate': 'represents',
#   'object': 'Oil and gas',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'image',
#   'predicate': 'has_icon',
#   'object': 'wind turbine icon',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  {'subject': 'wind turbine icon',
#   'predicate': 'represents',
#   'object': 'Power, utilities and renewables',
#   'source_file': 'gx-eri-decarbonization-report.pdf.pkl',
#   'page_number': 8},
#  ...]

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
URI = "neo4j+s://bd2636a6.databases.neo4j.io"
AUTH = ("neo4j", "Ahw-ABDgxBlTbISCbDTbzO4rG_Rub1vZYmowzkb47H0")

with GraphDatabase.driver(URI, auth=AUTH) as driver:
    driver.verify_connectivity()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_async_compat/network/_util.py:144, in NetworkUtil._dns_resolver(address, family)
#     143 try:
# --> 144     info = NetworkUtil.get_address_info(
#     145         address.host,
#     146         address.port,
#     147         family=family,
#     148         type=socket.SOCK_STREAM,
#     149     )
#     150 except OSError as e:
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_async_compat/network/_util.py:130, in NetworkUtil.get_address_info(host, port, family, type, proto, flags)
#     128 @staticmethod
#     129 def get_address_info(host, port, *, family=0, type=0, proto=0, flags=0):
# --> 130     return socket.getaddrinfo(host, port, family, type, proto, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5 AUTH = ("neo4j", "Ahw-ABDgxBlTbISCbDTbzO4rG_Rub1vZYmowzkb47H0")
#       7 with GraphDatabase.driver(URI, auth=AUTH) as driver:
# ----> 8     driver.verify_connectivity()
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/driver.py:1082, in Driver.verify_connectivity(self, **config)
#    1075     experimental_warn(
#    1076         "All configuration key-word arguments to "
#    1077         "verify_connectivity() are experimental. They might be "
#    1078         "changed or removed in any future version without prior "
#    1079         "notice."
#    1080     )
#    1081 session_config = self._read_session_config(config)
# -> 1082 self._get_server_info(session_config)
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/driver.py:1297, in Driver._get_server_info(self, session_config)
#    1295 def _get_server_info(self, session_config) -> ServerInfo:
#    1296     with self._session(session_config) as session:
# -> 1297         return session._get_server_info()
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:183, in Session._get_server_info(self)
#     181 def _get_server_info(self):
#     182     assert not self._connection
# --> 183     self._connect(READ_ACCESS, liveness_check_timeout=0)
#     184     server_info = self._connection.server_info
#     185     self._disconnect()
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/workspace.py:186, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     183     self._disconnect()
#     185 ssr_enabled = self._pool.ssr_enabled
# --> 186 target_db = self._get_routing_target_database(
#     187     acquire_auth, ssr_enabled=ssr_enabled
#     188 )
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)    196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#     198 acquire_kwargs_.update(acquire_kwargs)
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/workspace.py:260, in Workspace._get_routing_target_database(self, acquire_auth, ssr_enabled)
#     258 acquisition_timeout = self._config.connection_acquisition_timeout
#     259 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 260 self._pool.update_routing_table(
#     261     database=self._config.database,
#     262     imp_user=self._config.impersonated_user,
#     263     bookmarks=self._get_bookmarks(),
#     264     auth=acquire_auth,
#     265     acquisition_timeout=acquisition_timeout,
#     266     database_callback=self._make_db_resolution_callback(),
#     267 )
#     268 return AcquisitionDatabase(self._config.database)
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_pool.py:971, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     964     existing_routers = {self.address}
#     965     prefer_initial_routing_address = True
#     967 if (
#     968     prefer_initial_routing_address
#     969     and
#     970     # TODO: Test this state
# --> 971     self._update_routing_table_from(
#     972         self.address,
#     973         database=database,
#     974         imp_user=imp_user,
#     975         bookmarks=bookmarks,
#     976         auth=auth,
#     977         acquisition_timeout=acquisition_timeout,
#     978         database_callback=database_callback,
#     979     )
#     980 ):
#     981     # Why is only the first initial routing address used?
#     982     return
#     983 if self._update_routing_table_from(
#     984     *(existing_routers - {self.address}),
#     985     database=database,
#    (...)    990     database_callback=database_callback,
#     991 ):
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_pool.py:899, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     891     log.debug(
#     892         (
#     893             "[#0000]  _: <POOL> "
#    (...)    896         ", ".join(map(repr, routers)),
#     897     )
#     898 for router in routers:
# --> 899     for address in NetworkUtil.resolve_address(
#     900         router, resolver=self.pool_config.resolver
#     901     ):
#     902         new_routing_table = self.fetch_routing_table(
#     903             address=address,
#     904             acquisition_timeout=acquisition_timeout,
#    (...)    908             auth=auth,
#     909         )
#     910         if new_routing_table is not None:
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_async_compat/network/_util.py:196, in NetworkUtil.resolve_address(address, family, resolver)
#     194             yield address_dns_resolved
#     195 else:
# --> 196     for address_dns_resolved in NetworkUtil._dns_resolver(
#     197         address, family=family
#     198     ):
#     199         log.debug(
#     200             "[#0000]  _: <RESOLVE> dns resolver out: %s",
#     201             address_dns_resolved,
#     202         )
#     203         yield address_dns_resolved
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_async_compat/network/_util.py:151, in NetworkUtil._dns_resolver(address, family)
#     144     info = NetworkUtil.get_address_info(
#     145         address.host,
#     146         address.port,
#     147         family=family,
#     148         type=socket.SOCK_STREAM,
#     149     )
#     150 except OSError as e:
# --> 151     raise ValueError(f"Cannot resolve address {address}") from e
#     152 return _resolved_addresses_from_info(info, address._host_name)
#
# ValueError: Cannot resolve address bd2636a6.databases.neo4j.io:7687

# %%
def upload_triples(json_file_path):
    with open(json_file_path, 'r') as f:
        triples = json.load(f)
    
    with driver.session() as session:
        for triple in triples:
            subject = triple['subject']
            predicate = triple['predicate'].upper().replace(" ", "_")  # Neo4j relationship types uppercase & no spaces
            object_ = triple['object']
            source_file = triple.get('source_file', '')
            page_number = triple.get('page_number', -1)

            # Cypher query to merge nodes and relationship
            cypher_query = f"""
            MERGE (s:Entity {{name: $subject}})
            MERGE (o:Entity {{name: $object}})
            MERGE (s)-[r:{predicate} {{
                source_file: $source_file,
                page_number: $page_number
            }}]->(o)
            """

            session.run(
                cypher_query,
                subject=subject,
                object=object_,
                source_file=source_file,
                page_number=page_number
            )

    print("Upload complete!")

# %%
upload_triples("kg_triples.json")
# Out:
# /var/folders/0h/j84rsdwd49jbw1_d04_c5b3r0000gn/T/ipykernel_91608/3088159044.py:5: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 42I06} {gql_status_description: error: syntax error or access rule violation - invalid input. Invalid input '-', expected: a parameter, '&', '*', ':', 'WHERE', ']', '{' or '|'.} {message: 42I06: Invalid input '-', expected: a parameter, '&', '*', ':', 'WHERE', ']', '{' or '|'.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', '_position': {'offset': 119, 'column': 28, 'line': 4}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# CypherSyntaxError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 upload_triples("kg_triples.json")
#
# Cell In[51], line 23, in upload_triples(json_file_path)
#      13         # Cypher query to merge nodes and relationship
#      14         cypher_query = f"""
#      15         MERGE (s:Entity {{name: $subject}})
#      16         MERGE (o:Entity {{name: $object}})
#    (...)     20         }}]->(o)
#      21         """
# ---> 23         session.run(
#      24             cypher_query,
#      25             subject=subject,
#      26             object=object_,
#      27             source_file=source_file,
#      28             page_number=page_number
#      29         )
#      31 print("Upload complete!")
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:328, in Session.run(self, query, parameters, **kwargs)
#     326 bookmarks = self._get_bookmarks()
#     327 parameters = dict(parameters or {}, **kwargs)
# --> 328 self._auto_result._run(
#     329     query,
#     330     parameters,
#     331     self._config.database,
#     332     self._config.impersonated_user,
#     333     self._config.default_access_mode,
#     334     bookmarks,
#     335     self._config.notifications_min_severity,
#     336     self._config.notifications_disabled_classifications,
#     337 )
#     339 return self._auto_result
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/work/result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File ~/Documents/UTS_AISkillAssessment/KnowledgeGraphBasedRag/job_trends_agent/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input '-': expected a parameter, '&', '*', ':', 'WHERE', ']', '{' or '|' (line 4, column 28 (offset: 119))
# "            MERGE (s)-[r:CO-SUPERVISOR {"
#                             ^}
